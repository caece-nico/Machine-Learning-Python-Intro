# %%
"""
Ejempo de funcion para visualizar relaciones entrde dos variabels numericas
"""
# Out:
# '\nEjempo de funcion para visualizar relaciones entrde dos variabels numericas\n'

# %%
import seaborn as sea
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = 'Automobile price data _Raw_.csv'
data = pd.read_csv(url)
data[1:5]
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# ...

# %%
##creamos la fucion para eliminar guiones y combertir a numerico lo ue es objeto

def limpia_datos(data):
    
    import numpy as np
    import pandas as pd
    
    columns = data.columns
    data.columns = [str.replace('-','_') for str in columns]
    
    ## buscamos los ? en los varables que queremos hacer numericas
    
    columns = ['price', 'bore', 'stroke', 'horsepower', 'peak_rpm']
    for col in columns:
        data.loc[data[col]=='?',col]=np.nan
        data[col].dropna(axis=0,inplace=True)
        
    for col in columns:
        data[col] = pd.to_numeric(data[col])
        
    return data

# %%
limpia_datos(data)
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
data.dtypes
# Out:
# symboling              int64
# normalized_losses     object
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
## Creamos un grafico de estilo scatter plot para comprara varias variables numericas contra la variable precio.

def crea_scatter_plot(data, x_col, y_col = 'price'):
    for col in x_col:
        fig = plt.figure(figsize=(7,6))
        ax = fig.gca()
        data.plot.scatter(col, y_col, ax = ax)
        #ax.set_title('Relacion entre la variable: ' + y_col + ' vs ' + col)
        ax.set_xlabel(col)
        ax.set_ylabel(y_col)
        plt.show()

# %%
num_cols = ['curb_weight', 'engine_size', 'horsepower', 'city_mpg']
crea_scatter_plot(data,num_cols)

# %%
## estas vaiables parecen ser lineales asique seguramente las usaremos en un alg de ML

# %%
crea_scatter_plot(data,['horsepower'],'engine_size')

# %%
## estas variables no parecen tener relacion, asino lo mas probables es que no las usemos.
